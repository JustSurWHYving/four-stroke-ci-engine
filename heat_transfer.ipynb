# %% [markdown]
# ## Imports

# %%
from utils.heat_transfer_modelling import HeatTransferModel

# %% [markdown]
# ## Results Plotting

# %%
model = HeatTransferModel()
model.plot_results()
# Out:
# c:\Users\Ashish Prajapati\Documents\Repositories\four-stroke-ci-engine\utils\heat_transfer_modelling.py:180: RuntimeWarning: invalid value encountered in scalar power
#   return 3.26 * (self.bore ** -0.2) * (p ** 0.8) * (T ** -0.55) * (gas_velocity ** 0.8)
# c:\ProgramData\miniconda3\envs\ht\Lib\site-packages\scipy\integrate\_ivp\lsoda.py:161: UserWarning: lsoda: Excess accuracy requested (tolerances too small).
#   solver._y, solver.t = integrator.run(
