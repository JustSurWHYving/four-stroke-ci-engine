# %% [markdown]
# ## Imports

# %%
from utils.heat_transfer_modelling import HeatTransferModel

# %% [markdown]
# ## Results Plotting

# %%
model = HeatTransferModel()
model.plot_results()
# Out:
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 = -0.8877280917266D+01   r2 =                  NaN
# /home/ashish/Developer/four-stroke-ci-engine/utils/heat_transfer_modelling.py:180: RuntimeWarning: invalid value encountered in scalar power
#   return 3.26 * (self.bore ** -0.2) * (p ** 0.8) * (T ** -0.55) * (gas_velocity ** 0.8)
# /home/ashish/.miniconda/envs/ht/lib/python3.12/site-packages/scipy/integrate/_ivp/lsoda.py:222: RuntimeWarning: divide by zero encountered in divide
#   x = ((t - self.t) / self.h) ** self.p[:, None]
# /home/ashish/.miniconda/envs/ht/lib/python3.12/site-packages/scipy/integrate/_ivp/lsoda.py:161: UserWarning: lsoda: Excess accuracy requested (tolerances too small).
#   solver._y, solver.t = integrator.run(
